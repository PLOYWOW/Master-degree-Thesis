# %%
import pandas as pd

n = ['image', 'blank1', 'state', 'blank2', 'truth_x', 'truth_y', 'blank3', 'estimate_x', 'estimate_y', 'blank4', 'error']
df = pd.read_csv('C:/Users/ployw/OneDrive/Desktop/Kyutech/Lab/Thesis/Result/Pupil detection/D2 Data set/AlexNet/result.csv',header = None,names=n)
df
# Out:
#                                         image  blank1  state  blank2  truth_x  \
# 0       ../VDO_resize/kan1/2017052212_0/0.png     NaN      0     NaN     55.0
# 1       ../VDO_resize/kan1/2017052212_0/1.png     NaN      1     NaN     54.0
# 2       ../VDO_resize/kan1/2017052212_0/2.png     NaN      1     NaN     54.0
# 3       ../VDO_resize/kan1/2017052212_0/3.png     NaN      0     NaN     55.0
# 4       ../VDO_resize/kan1/2017052212_0/4.png     NaN      1     NaN     55.0
# ...                                       ...     ...    ...     ...      ...
# 1955  ../VDO_resize/kan1/2017052212_48/35.png     NaN      0     NaN     62.0
# 1956  ../VDO_resize/kan1/2017052212_48/36.png     NaN      0     NaN     62.0
# 1957  ../VDO_resize/kan1/2017052212_48/37.png     NaN      0     NaN     63.0
# 1958  ../VDO_resize/kan1/2017052212_48/38.png     NaN      0     NaN     63.0
# 1959  ../VDO_resize/kan1/2017052212_48/39.png     NaN      0     NaN     62.0
#
# ...

# %%
truth_x = list(df["truth_x"])
print(truth_x)
# Out:
# [55.0, 54.0, 54.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 55.0, 56.0, 56.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 54.0, 58.0, 57.0, 57.0, 57.0, 57.0, 56.0, 57.0, 57.0, 57.0, 57.0, 57.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 57.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 56.0, 55.0, 56.0, 55.0, 55.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 37.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 51.0, 48.0, 50.0, 50.0, 50.0, 50.0, 51.0, 51.0, 51.0, 51.0, 51.0, 50.0, 50.0, 49.0, 49.0, 49.0, 49.0, 49.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 49.0, 49.0, 49.0, 48.0, 49.0, 49.0, 48.0, 48.0, 48.0, 48.0, 48.0, 67.0, 67.0, 66.0, 66.0, 66.0, 67.0, 6
# ...

# %%
truth_y = list(df["truth_y"])
estimate_x = list(df["estimate_x"])
estimate_y = list(df["estimate_y"])

# %%
truth_x = pd.DataFrame(truth_x, columns = ['truth_x'])
truth_y = pd.DataFrame(truth_y, columns = ['truth_y'])
estimate_x = pd.DataFrame(estimate_x, columns = ['estimate_x'])
estimate_y = pd.DataFrame(estimate_y, columns = ['estimate_y'])

# %%
truth_x.to_csv("C:/Users/ployw/OneDrive/Desktop/Kyutech/Lab/Code/Real/Plotting Points/truth_x.csv")
truth_y.to_csv("C:/Users/ployw/OneDrive/Desktop/Kyutech/Lab/Code/Real/Plotting Points/truth_y.csv")
estimate_x.to_csv("C:/Users/ployw/OneDrive/Desktop/Kyutech/Lab/Code/Real/Plotting Points/estimate_x.csv")
estimate_y.to_csv("C:/Users/ployw/OneDrive/Desktop/Kyutech/Lab/Code/Real/Plotting Points/estimate_y.csv")
