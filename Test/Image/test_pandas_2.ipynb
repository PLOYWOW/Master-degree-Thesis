# %%
import pandas as pd

df = pd.read_csv('test.csv')
df
# Out:
#       Unnamed: 0                                    image  state  truth_x  \
# 0              0    ../VDO_resize/kan1/2017052212_0/0.png      0     55.0
# 1              1    ../VDO_resize/kan1/2017052212_0/1.png      1     54.0
# 2              2    ../VDO_resize/kan1/2017052212_0/2.png      1     54.0
# 3              3    ../VDO_resize/kan1/2017052212_0/3.png      0     55.0
# 4              4    ../VDO_resize/kan1/2017052212_0/4.png      1     55.0
# ...          ...                                      ...    ...      ...
# 1955        1955  ../VDO_resize/kan1/2017052212_48/35.png      0     62.0
# 1956        1956  ../VDO_resize/kan1/2017052212_48/36.png      0     62.0
# 1957        1957  ../VDO_resize/kan1/2017052212_48/37.png      0     63.0
# 1958        1958  ../VDO_resize/kan1/2017052212_48/38.png      0     63.0
# 1959        1959  ../VDO_resize/kan1/2017052212_48/39.png      0     62.0
#
#       truth_y  estimate_x  estimate_y     error
# ...

# %%
image = list(df["image"])
