# %%
import pandas as pd

# %%
#image file path = image 
#eye state label = state
#ground truth of pupil center x = truth_x 
#ground truth of pupil center y = truth_y
#estimate result of pupil center detection x = estimate_x
#estimate result of pupil center detection y = estimate_y
#error = error
n = ['image', 'blank1', 'state', 'blank2', 'truth_x', 'truth_y', 'blank3', 'estimate_x', 'estimate_y', 'blank4', 'error']
print(len(n))
df = pd.read_csv('C:/Users/ployw/OneDrive/Desktop/Kyutech/Lab/Thesis/Result/Pupil detection/D2 Data set/AlexNet/result.csv',header = None,names=n)
df.fillna(0, inplace=True)
df
# Out:
# 11
#                                         image  blank1  state  blank2  truth_x  \
# 0       ../VDO_resize/kan1/2017052212_0/0.png     0.0      0     0.0     55.0
# 1       ../VDO_resize/kan1/2017052212_0/1.png     0.0      1     0.0     54.0
# 2       ../VDO_resize/kan1/2017052212_0/2.png     0.0      1     0.0     54.0
# 3       ../VDO_resize/kan1/2017052212_0/3.png     0.0      0     0.0     55.0
# 4       ../VDO_resize/kan1/2017052212_0/4.png     0.0      1     0.0     55.0
# ...                                       ...     ...    ...     ...      ...
# 1955  ../VDO_resize/kan1/2017052212_48/35.png     0.0      0     0.0     62.0
# 1956  ../VDO_resize/kan1/2017052212_48/36.png     0.0      0     0.0     62.0
# 1957  ../VDO_resize/kan1/2017052212_48/37.png     0.0      0     0.0     63.0
# 1958  ../VDO_resize/kan1/2017052212_48/38.png     0.0      0     0.0     63.0
# 1959  ../VDO_resize/kan1/2017052212_48/39.png     0.0      0     0.0     62.0
#
# ...

# %%
dfw = df.drop(['blank1','blank2','blank3','blank4'], axis=1)
dfw
# Out:
#                                         image  state  truth_x  truth_y  \
# 0       ../VDO_resize/kan1/2017052212_0/0.png      0     55.0     42.0
# 1       ../VDO_resize/kan1/2017052212_0/1.png      1     54.0     43.0
# 2       ../VDO_resize/kan1/2017052212_0/2.png      1     54.0     43.0
# 3       ../VDO_resize/kan1/2017052212_0/3.png      0     55.0     42.0
# 4       ../VDO_resize/kan1/2017052212_0/4.png      1     55.0     42.0
# ...                                       ...    ...      ...      ...
# 1955  ../VDO_resize/kan1/2017052212_48/35.png      0     62.0     47.0
# 1956  ../VDO_resize/kan1/2017052212_48/36.png      0     62.0     47.0
# 1957  ../VDO_resize/kan1/2017052212_48/37.png      0     63.0     47.0
# 1958  ../VDO_resize/kan1/2017052212_48/38.png      0     63.0     47.0
# 1959  ../VDO_resize/kan1/2017052212_48/39.png      0     62.0     47.0
#
#       estimate_x  estimate_y     error
# 0      53.872128   39.189598  3.028276
# ...

# %%
dfw.to_csv('test.csv')

# %%
dfw["truth_x"][0]
# Out:
# 55.0

# %%
dfw["image"]
# Out:
# 0         ../VDO_resize/kan1/2017052212_0/0.png
# 1         ../VDO_resize/kan1/2017052212_0/1.png
# 2         ../VDO_resize/kan1/2017052212_0/2.png
# 3         ../VDO_resize/kan1/2017052212_0/3.png
# 4         ../VDO_resize/kan1/2017052212_0/4.png
#                          ...
# 1955    ../VDO_resize/kan1/2017052212_48/35.png
# 1956    ../VDO_resize/kan1/2017052212_48/36.png
# 1957    ../VDO_resize/kan1/2017052212_48/37.png
# 1958    ../VDO_resize/kan1/2017052212_48/38.png
# 1959    ../VDO_resize/kan1/2017052212_48/39.png
# Name: image, Length: 1960, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17172/181329403.py in <module>
# ----> 1 aa = list(dfw["truth_x"])
#
# TypeError: 'str' object is not callable
